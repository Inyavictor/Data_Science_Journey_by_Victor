# %% [markdown]
# DAY5 EXERCISE OF 30 DAYS OF PYTHON

# %%
Empty_list = []

# %%
Professional_list = ['Data Scientist', 'Data Analyst', 'Data Engineer', 'Machine Learning Engineer', 'Data Architect']  
print(Professional_list)
# Out:
# ['Data Scientist', 'Data Analyst', 'Data Engineer', 'Machine Learning Engineer', 'Data Architect']

# %%
Professional_list = ['Data Scientist', 'Data Analyst', 'Data Engineer', 'Machine Learning Engineer', 'Data Architect']  
print({"Profession": Professional_list})
Professional_list
# Out:
# {'Profession': ['Data Scientist', 'Data Analyst', 'Data Engineer', 'Machine Learning Engineer', 'Data Architect']}
# ['Data Scientist',
#  'Data Analyst',
#  'Data Engineer',
#  'Machine Learning Engineer',
#  'Data Architect']

# %%
print(len(Professional_list))
# Out:
# 5

# %%
print(Professional_list[0])
# Out:
# Data Scientist

# %%
print(Professional_list[2])
# Out:
# Data Engineer

# %%
print(Professional_list[-1])
# Out:
# Data Architect

# %%
My_profile = ['Victor', 30, {'Height': 2.3}, 'Marital Status: Single', 'Address: 127 Ilogbo Street, Lagos, Nigeria']
print(My_profile)
My_profile
# Out:
# ['Victor', 30, {'Height': 2.3}, 'Marital Status: Single', 'Address: 127 Ilogbo Street, Lagos, Nigeria']
# ['Victor',
#  30,
#  {'Height': 2.3},
#  'Marital Status: Single',
#  'Address: 127 Ilogbo Street, Lagos, Nigeria']

# %%
it_Company = ['Google', 'Facebook', 'Amazon', 'Apple', 'Microsoft']
print(it_Company)
# Out:
# ['Google', 'Facebook', 'Amazon', 'Apple', 'Microsoft']

# %%
print(len(it_Company))
# Out:
# 5

# %%
print(it_Company[0])
# Out:
# Google

# %%
print(it_Company[2])
# Out:
# Amazon

# %%
print(it_Company[-1])
# Out:
# Microsoft

# %%
modified_list = it_Company
modified_list[0] = 'IBM'
print(modified_list)
# Out:
# ['IBM', 'Facebook', 'Netflix', 'Microsoft', 'Netflix']

# %%
modified_list.append('Netflix')
print(modified_list)
# Out:
# ['IBM', 'Facebook', 'Netflix', 'Microsoft', 'Netflix', 'Netflix']
