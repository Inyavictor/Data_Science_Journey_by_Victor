# %% [markdown]
# DAY03 EXERCISE

# %%
#no.1
My_age = 29
print(My_age)
# Out:
# 29

# %%
#no.2
My_height = 1.75
print(My_height)
# Out:
# 1.75

# %%
#no.3
Complex_number = 1 + 2j
print(Complex_number)
# Out:
# (1+2j)

# %%
#no.4
Base = input("Enter base: ")
Height = input("Enter height: ")
Area_of_triangle = 0.5 * float(Base) * float(Height)
print(int(Area_of_triangle))
# Out:
# 25

# %%
#no.5
Side_a = input("Enter side a: ")
Side_b = input("Enter side b: ")
Side_c = input("Enter side c: ")
Perimeter_of_triangle = float(Side_a) + float(Side_b) + float(Side_c)
print(int(Perimeter_of_triangle))
# Out:
# 12

# %%
#no.6
length= float(input("Enter length: "))
width = float(input("Enter width: "))
Area_of_rectangle = length * width
perimeter_of_rectangle = 2 * (length + width)    
print(int(Area_of_rectangle))
print(int(perimeter_of_rectangle))
# Out:
# 200
# 60

# %%
#no.7
Radius = input(("Enter Radius: "))
Area_of_circle = 3.14 * float(Radius) ** 2
Circumference_of_circle = 2 * 3.14 * float(Radius)
print(int(Area_of_circle))
print(int(Circumference_of_circle))
# Out:
# 452
# 75

# %%
#no.8

# %%
#no.9
A = (2,2)
B = (6,10)
slope = (B[1] - A[1]) / (B[0] - A[0])
print(slope)
# Out:
# 2.0
