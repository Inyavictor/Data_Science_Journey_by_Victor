# %% [markdown]
#   MODULE 2 EXERCISE
#   Level 1:

# %%
#'DAY2: 30 Days of Python Programming'

# %%
First_name = 'Victor'
Last_name = 'Inya'
Full_name = (First_name + ' ' + Last_name)
Country = 'Nigeria'
City = 'Lagos'
Age = 29
Year = 2025
is_married = False
is_data_scientist = True
is_light_on = True
Multiple_variable = First_name, Last_name, Country, City, Age, Year, is_married, is_data_scientist, is_light_on
print(First_name)
print(Last_name)
print(Full_name)
print(Country)
print(City)
print(Age)
print(Year)
print(is_married)
print(is_data_scientist)
print(is_light_on)
print(Multiple_variable)
# Out:
# Victor
# Inya
# Victor Inya
# Nigeria
# Lagos
# 29
# 2025
# False
# True
# True
# ('Victor', 'Inya', 'Nigeria', 'Lagos', 29, 2025, False, True, True)

# %%
#Level 2
#No.1
print(type(First_name))
print(type(Last_name))
print(type(Full_name))
print(type(Country))
print(type(City))
print(type(Age))
print(type(Year))
print(type(is_married))
print(type(is_data_scientist))
print(type(is_light_on))
print(type(Multiple_variable))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'tuple'>

# %%
#No.2 and 3
First_name = 'Victor'
print(len(First_name))
Last_name = 'Inya'
print(len(Last_name))
# Out:
# 6
# 4

# %%
#No.4 and 5
num_one = 5
num_two = 4
total = num_one + num_two
print(total)
# Out:
# 9

# %%
#No.6
num_one = 5
num_two = 4
diff = num_one - num_two
print(diff)
# Out:
# 1

# %%
#No.7
product = num_one * num_two
print(product)
# Out:
# 20

# %%
#no.8
division = num_one / num_two
print(division)
# Out:
# 1.25

# %%
#no.9
variable_remainder = num_one % num_two
print(variable_remainder)
# Out:
# 1

# %%
#no.10
variable_exponent = num_one ** num_two
print(variable_exponent)
# Out:
# 625

# %%
#no.11
floor_division = num_one // num_two
print(floor_division)
# Out:
# 1

# %%
#no.12
radius = 30
pi = 3.14
area_of_circle = pi * radius ** 2
print(area_of_circle)
# Out:
# 2826.0

# %%
circumference_of_circle = 2 * pi * radius
print(circumference_of_circle)
# Out:
# 188.4

# %%
radius =(input('Enter the radius of a circle: '))
area_of_circle = pi * float(radius) ** 2
print('The area of the circle is: ' + str(area_of_circle))
# Out:
# The area of the circle is: 2826.0

# %%
#no.13
first_name = input('Enter your first name: ')
last_name = input('Enter your last name: ')
full_name = input('Enter your full name: ')
country = input('Enter your country: ')
age = input('Enter your age: ')
print('My full name is: ' + full_name)
print('My country is: ' + country)
print('My age is: ' + age)
print('My first name is: ' + first_name)
print('My last name is: ' + last_name)
# Out:
# My full name is: Victor Inya
# My country is: Nigeria
# My age is: 29
# My first name is: Victor
# My last name is: Inya

# %%
#no.14
help()
# Out:
# Welcome to Python 3.13's help utility! If this is your first time using
# Python, you should definitely check out the tutorial at
# https://docs.python.org/3.13/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To get a list of available
# modules, keywords, symbols, or topics, enter "modules", "keywords",
# "symbols", or "topics".
#
# Each module also comes with a one-line summary of what it does; to list
# the modules whose name or summary contain a given string such as "spam",
# enter "modules spam".
#
# To quit this help utility and return to the interpreter,
# enter "q", "quit" or "exit".
#
#
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# ...
