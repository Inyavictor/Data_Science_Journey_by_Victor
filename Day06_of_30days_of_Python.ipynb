# %% [markdown]
# DAY6 OF 30 DAYS OF PYTHON

# %%
Empty_tuple = ()

# %%
Family = ('victor','john','michael','susan','linda')
print(Family)
# Out:
# ('victor', 'john', 'michael', 'susan', 'linda')

# %%
Brothers = ('Nnamdi','Chinedu','Chukwuemeka')
Sisters = ('Chidinma','Chiamaka','Chisom')
Siblings = Brothers + Sisters
print(Siblings)
# Out:
# ('Nnamdi', 'Chinedu', 'Chukwuemeka', 'Chidinma', 'Chiamaka', 'Chisom')

# %%
print(len(Siblings))
# Out:
# 6

# %%
Siblings = list(Siblings)
print(Siblings)
# Out:
# ['Nnamdi', 'Chinedu', 'Chukwuemeka', 'Chidinma', 'Chiamaka', 'Chisom']

# %%
Main_family = Siblings.copy()
print(Main_family)
# Out:
# ['Nnamdi', 'Chinedu', 'Chukwuemeka', 'Chidinma', 'Chiamaka', 'Chisom']

# %%
del Main_family

# %%
My_Family = tuple(Siblings)
print(My_Family)
# Out:
# ('Nnamdi', 'Chinedu', 'Chukwuemeka', 'Chidinma', 'Chiamaka', 'Chisom')

# %%
Parent = ('father','mother')
My_family_members = Parent + My_Family
print(My_family_members)
# Out:
# ('father', 'mother', 'Nnamdi', 'Chinedu', 'Chukwuemeka', 'Chidinma', 'Chiamaka', 'Chisom')

# %%
My_home = list(My_family_members)
print(My_home)
# Out:
# ['father', 'mother', 'Nnamdi', 'Chinedu', 'Chukwuemeka', 'Chidinma', 'Chiamaka', 'Chisom']

# %%
My_family_members[0:2]
print(My_family_members[0:2])
# Out:
# ('father', 'mother')

# %%
My_family_members[3:]
print(My_family_members[3:])
# Out:
# ('Chinedu', 'Chukwuemeka', 'Chidinma', 'Chiamaka', 'Chisom')

# %%
Fruits = ('banana','orange','mango','lemon')
Vegetables = ('Tomato','Cucumber','Onion','Carrot')
Animal_products = ('milk','meat','egg','cheese')
Food_stuff_tp = Fruits + Vegetables + Animal_products 
print(Food_stuff_tp)
# Out:
# ('banana', 'orange', 'mango', 'lemon', 'Tomato', 'Cucumber', 'Onion', 'Carrot', 'milk', 'meat', 'egg', 'cheese')

# %%
Food_stuff_lst = list(Food_stuff_tp)
print(Food_stuff_lst)
# Out:
# ['banana', 'orange', 'mango', 'lemon', 'Tomato', 'Cucumber', 'Onion', 'Carrot', 'milk', 'meat', 'egg', 'cheese']

# %%
print(Food_stuff_lst[6])
# Out:
# Onion

# %%
print(Food_stuff_lst[0:3])
# Out:
# ['banana', 'orange', 'mango']

# %%
print(Food_stuff_lst[-3:])
# Out:
# ['meat', 'egg', 'cheese']

# %%
del Food_stuff_tp

# %%
nordic_countries = ('Denmark', 'Finland', 'Iceland', 'Norway', 'Sweden')
'estonia'in nordic_countries
# Out:
# False

# %%
'Iceland'in nordic_countries
# Out:
# True
