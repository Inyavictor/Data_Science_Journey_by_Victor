# %% [markdown]
# This is my first python program

# %%
victor = " I am programmer!"
print (victor)
# Out:
#  I am programmer!

# %%
victor.upper()
# Out:
# ' I AM PROGRAMMER!'

# %%
victor.lower()
# Out:
# ' i am programmer!'

# %%
User = "Victor"
Password = 23456778

f'Welcome {User}! your new password is {Password}'
# Out:
# 'Welcome Victor! your new password is 23456778'

# %%
math = 2/7
print(math)
# Out:
# 0.2857142857142857

# %%
print(round(math, 4))
# Out:
# 0.2857

# %%
print(int(math))
# Out:
# 0
