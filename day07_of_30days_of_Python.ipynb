# %% [markdown]
# DAY07 0F 30DAYS OF PYTHON

# %%
it_companies = {'Facebook','Google','Microsoft','Apple','IBM','Oracle','Amazon'}
print(it_companies)
# Out:
# {'Oracle', 'Microsoft', 'Facebook', 'Apple', 'Amazon', 'Google', 'IBM'}

# %%
print(len(it_companies))
# Out:
# 7

# %%
it_companies.add('Twitter')
print(it_companies)
# Out:
# {'Oracle', 'Microsoft', 'Twitter', 'Facebook', 'Apple', 'Amazon', 'Google', 'IBM'}

# %%
it_companies.update(['Meta', 'Netflix'])
print(it_companies)
# Out:
# {'Amazon', 'IBM', 'Facebook', 'Twitter', 'Google', 'Netflix', 'Oracle', 'Meta', 'Apple', 'Microsoft'}

# %%
it_companies.remove('IBM')
print(it_companies)
# Out:
# {'Amazon', 'Facebook', 'Twitter', 'Google', 'Netflix', 'Oracle', 'Meta', 'Apple', 'Microsoft'}

# %%
A = {19, 22, 24, 20, 25, 26}
B = {19, 22, 20, 25, 26, 24, 28, 27}    
age = {22, 19, 24, 25, 26, 24, 25, 24}

# %%
A = {19, 22, 24, 20, 25, 26}
B = {19, 22, 20, 25, 26, 24, 28, 27}    
age = {22, 19, 24, 25, 26, 24, 25, 24}
join = A.union(B)
print(join)
# Out:
# {19, 20, 22, 24, 25, 26, 27, 28}

# %%
Subset = A.issubset(B)
print(Subset)
# Out:
# True

# %%
disjoint = A.isdisjoint(B)
print(disjoint)
# Out:
# False

# %%
join_multiple = A.union(B, age)
print(join_multiple)
# Out:
# {19, 20, 22, 24, 25, 26, 27, 28}

# %%
symmetric_diff = A.symmetric_difference(B)
print(symmetric_diff)
# Out:
# {27, 28}

# %%
del A 
del B
del age
